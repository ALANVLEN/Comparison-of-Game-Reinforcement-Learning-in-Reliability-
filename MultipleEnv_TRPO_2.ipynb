# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3 import DQN
#from stable_baselines import TRPO
from stable_baselines3 import A2C
from gym import Env
from gym.spaces import MultiBinary, Box
import numpy as np
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_util import make_vec_env
import gym
from stable_baselines3.common.atari_wrappers import AtariWrapper
from gym import Wrapper
from stable_baselines3.common.vec_env import VecFrameStack, VecTransposeImage

# %%
# Create custom environment
class Mario(Wrapper):
    def __init__(self, env):
        super(Mario, self).__init__(env)
        self._current_score = 0

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        reward += (info['score'] - self._current_score) / 40.0
        self._current_score = info['score']
        if done:
            if info['flag_get']:
                print('We got it!!!!!')
                reward += 350.0
            else:
                reward -= 50.0
        return state, reward / 10.0, done, info

    def reset(self):
        """Reset the environment and return the initial observation."""
        return self.env.reset()

    def render(self, *args, **kwargs):
        self.env.render()

    def close(self):
        self.env.close()

# %%
monitor_dir = './A2C_4_MA_monitor_log'
os.makedirs(monitor_dir,exist_ok=True)

# %%
def mario_wrapper(env):
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = AtariWrapper(env, terminal_on_life_loss=False, clip_reward=False)
    env = Mario(env)
    return env

# %%
env = make_vec_env('SuperMarioBros-v0', n_envs=16, seed=3994448089, wrapper_class=mario_wrapper)

env = VecFrameStack(env,4,channels_order='last')
env = VecTransposeImage(env)

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, save_model_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, 'best_model/')
        self.best_mean_reward = -np.inf

    # def _init_callback(self) -> None:
    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    # def _on_step(self) -> bool:
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ',self.n_calls)
            model_path1 = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path1)

        return True

# %%
save_model_dir = './A2C_4_MA_train'
callback1 = SaveOnBestTrainingRewardCallback(10000, save_model_dir)

# %% [markdown]
# # Training

# %%
model_param_1={
 #    'n_steps': 7424,
  'gamma': 0.8692871366327747,
    #'gamma': 0.9357882315009981,
  'learning_rate': 6.442559213980066e-05,
    #'learning_rate': 3.0976565201136994e-05,
 # 'clip_range': 0.31688308594665404,
 # 'gae_lambda': 0.8710254680014865
}

# %%
tensorboard_log = r'./A2C_4_MA_tensorboard_log'

model = A2C("CnnPolicy", env, verbose=1,
            tensorboard_log = tensorboard_log,**model_param_1)
model.learn(total_timesteps=4000000,callback=callback1)
model.save("mario_model")
# Out:
# Using cuda device
# Logging to ./A2C_4_MA_tensorboard_log\A2C_1
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.44e+03 |
# |    ep_rew_mean        | 1.76e+03 |
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 100      |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.829    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 99       |
# |    policy_loss        | 0.466    |
# |    value_loss         | 0.66     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.7e+03  |
# |    ep_rew_mean        | 1.59e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 200      |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.904    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 199      |
# |    policy_loss        | 0.33     |
# |    value_loss         | 0.921    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.21e+03 |
# |    ep_rew_mean        | 1.68e+03 |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 300      |
# |    time_elapsed       | 236      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | 0.945    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0718   |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.48e+03 |
# |    ep_rew_mean        | 1.76e+03 |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 400      |
# |    time_elapsed       | 316      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.817    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 399      |
# |    policy_loss        | -0.347   |
# |    value_loss         | 1.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.56e+03 |
# |    ep_rew_mean        | 1.78e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 500      |
# |    time_elapsed       | 396      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0.94     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 499      |
# |    policy_loss        | -0.242   |
# |    value_loss         | 0.538    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.43e+03 |
# |    ep_rew_mean        | 1.78e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 600      |
# |    time_elapsed       | 476      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.821    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0529   |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.28e+03 |
# |    ep_rew_mean        | 1.8e+03  |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 700      |
# |    time_elapsed       | 558      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0.621    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 699      |
# |    policy_loss        | 0.192    |
# |    value_loss         | 2.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.16e+03 |
# |    ep_rew_mean        | 1.84e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 800      |
# |    time_elapsed       | 636      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.713    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 799      |
# |    policy_loss        | -1.32    |
# |    value_loss         | 3.62     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.93e+03 |
# |    ep_rew_mean        | 1.85e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 900      |
# |    time_elapsed       | 715      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.758    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0634   |
# |    value_loss         | 1.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.54e+03 |
# |    ep_rew_mean        | 1.85e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1000     |
# |    time_elapsed       | 797      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.336    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 999      |
# |    policy_loss        | -0.778   |
# |    value_loss         | 9.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.36e+03 |
# |    ep_rew_mean        | 1.9e+03  |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1100     |
# |    time_elapsed       | 878      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.306    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.019   |
# |    value_loss         | 4.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.31e+03 |
# |    ep_rew_mean        | 1.94e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1200     |
# |    time_elapsed       | 959      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.287    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.615   |
# |    value_loss         | 7.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.28e+03 |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1300     |
# |    time_elapsed       | 1038     |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.865    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.275    |
# |    value_loss         | 1.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.24e+03 |
# |    ep_rew_mean        | 1.98e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1400     |
# |    time_elapsed       | 1119     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.557    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0769   |
# |    value_loss         | 3.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.22e+03 |
# |    ep_rew_mean        | 1.95e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1500     |
# |    time_elapsed       | 1200     |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.75    |
# |    explained_variance | 0.573    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.27    |
# |    value_loss         | 2.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+03 |
# |    ep_rew_mean        | 1.85e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1600     |
# |    time_elapsed       | 1279     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | 0.808    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.6      |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 987      |
# |    ep_rew_mean        | 1.76e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1700     |
# |    time_elapsed       | 1358     |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | 0.733    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.088    |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 943      |
# |    ep_rew_mean        | 1.7e+03  |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1800     |
# |    time_elapsed       | 1437     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.489   |
# |    explained_variance | 0.835    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0622  |
# |    value_loss         | 1.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 941      |
# |    ep_rew_mean        | 1.72e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 1900     |
# |    time_elapsed       | 1519     |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | 0.859    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.0519   |
# |    value_loss         | 0.668    |
# ------------------------------------
# self.n_calls:  10000
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 955      |
# |    ep_rew_mean        | 1.72e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2000     |
# |    time_elapsed       | 1600     |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.812    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0731  |
# |    value_loss         | 1.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 977      |
# |    ep_rew_mean        | 1.76e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 2100     |
# |    time_elapsed       | 1679     |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -0.606   |
# |    explained_variance | 0.77     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.349    |
# |    value_loss         | 1.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.02e+03 |
# |    ep_rew_mean        | 1.82e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2200     |
# |    time_elapsed       | 1761     |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 0.685    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.109    |
# |    value_loss         | 1.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.06e+03 |
# |    ep_rew_mean        | 1.87e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2300     |
# |    time_elapsed       | 1841     |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.714   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.00599  |
# |    value_loss         | 1.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.1e+03  |
# |    ep_rew_mean        | 1.95e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2400     |
# |    time_elapsed       | 1922     |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.628   |
# |    explained_variance | 0.672    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0361   |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+03 |
# |    ep_rew_mean        | 1.86e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2500     |
# |    time_elapsed       | 2000     |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | 0.819    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.131    |
# |    value_loss         | 0.601    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 993      |
# |    ep_rew_mean        | 1.78e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2600     |
# |    time_elapsed       | 2080     |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -0.664   |
# |    explained_variance | 0.627    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0226  |
# |    value_loss         | 1.86     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 941      |
# |    ep_rew_mean        | 1.71e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 2700     |
# |    time_elapsed       | 2158     |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | 0.803    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.421    |
# |    value_loss         | 1.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 953      |
# |    ep_rew_mean        | 1.74e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 2800     |
# |    time_elapsed       | 2239     |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -0.764   |
# |    explained_variance | 0.847    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.457    |
# |    value_loss         | 1.19     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1e+03    |
# |    ep_rew_mean        | 1.81e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 2900     |
# |    time_elapsed       | 2319     |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.727    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.114    |
# |    value_loss         | 1.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 1.91e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 3000     |
# |    time_elapsed       | 2398     |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -0.567   |
# |    explained_variance | 0.795    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.179    |
# |    value_loss         | 1.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.1e+03  |
# |    ep_rew_mean        | 1.96e+03 |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 3100     |
# |    time_elapsed       | 2479     |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | 0.812    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.33     |
# |    value_loss         | 0.697    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+03 |
# |    ep_rew_mean        | 1.98e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3200     |
# |    time_elapsed       | 2560     |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -0.663   |
# |    explained_variance | 0.693    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.299    |
# |    value_loss         | 2.64     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.1e+03  |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3300     |
# |    time_elapsed       | 2643     |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -0.678   |
# |    explained_variance | 0.867    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000697 |
# |    value_loss         | 0.892    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 1.98e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3400     |
# |    time_elapsed       | 2724     |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | 0.442    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0147   |
# |    value_loss         | 3.43     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.03e+03 |
# |    ep_rew_mean        | 1.86e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3500     |
# |    time_elapsed       | 2806     |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -0.595   |
# |    explained_variance | 0.659    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.512    |
# |    value_loss         | 2.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 957      |
# |    ep_rew_mean        | 1.69e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3600     |
# |    time_elapsed       | 2885     |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.473   |
# |    explained_variance | 0.843    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0414   |
# |    value_loss         | 0.563    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 989      |
# |    ep_rew_mean        | 1.68e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3700     |
# |    time_elapsed       | 2966     |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -0.495   |
# |    explained_variance | 0.755    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.369   |
# |    value_loss         | 1.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 991      |
# |    ep_rew_mean        | 1.69e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3800     |
# |    time_elapsed       | 3048     |
# |    total_timesteps    | 304000   |
# | train/                |          |
# |    entropy_loss       | -0.516   |
# |    explained_variance | 0.556    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.64    |
# |    value_loss         | 5.86     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.01e+03 |
# |    ep_rew_mean        | 1.73e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 3900     |
# |    time_elapsed       | 3129     |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0.412    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0516  |
# |    value_loss         | 6.44     |
# ------------------------------------
# self.n_calls:  20000
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 1.85e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4000     |
# |    time_elapsed       | 3208     |
# |    total_timesteps    | 320000   |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.46     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.225   |
# |    value_loss         | 7.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.03e+03 |
# |    ep_rew_mean        | 1.83e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4100     |
# |    time_elapsed       | 3289     |
# |    total_timesteps    | 328000   |
# | train/                |          |
# |    entropy_loss       | -0.813   |
# |    explained_variance | 0.845    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.295   |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+03 |
# |    ep_rew_mean        | 1.89e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4200     |
# |    time_elapsed       | 3368     |
# |    total_timesteps    | 336000   |
# | train/                |          |
# |    entropy_loss       | -0.714   |
# |    explained_variance | 0.88     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.281    |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 984      |
# |    ep_rew_mean        | 1.8e+03  |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4300     |
# |    time_elapsed       | 3447     |
# |    total_timesteps    | 344000   |
# | train/                |          |
# |    entropy_loss       | -0.557   |
# |    explained_variance | 0.866    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000138 |
# |    value_loss         | 0.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 968      |
# |    ep_rew_mean        | 1.73e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4400     |
# |    time_elapsed       | 3526     |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.404   |
# |    explained_variance | 0.526    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.239   |
# |    value_loss         | 5.45     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 954      |
# |    ep_rew_mean        | 1.66e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4500     |
# |    time_elapsed       | 3605     |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -0.31    |
# |    explained_variance | 0.937    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0937  |
# |    value_loss         | 0.588    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 954      |
# |    ep_rew_mean        | 1.57e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4600     |
# |    time_elapsed       | 3685     |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.438   |
# |    explained_variance | 0.817    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.141   |
# |    value_loss         | 1.22     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 969      |
# |    ep_rew_mean        | 1.58e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4700     |
# |    time_elapsed       | 3765     |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.696   |
# |    explained_variance | 0.853    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.242    |
# |    value_loss         | 1.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 974      |
# |    ep_rew_mean        | 1.62e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4800     |
# |    time_elapsed       | 3846     |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.694   |
# |    explained_variance | 0.342    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0619  |
# |    value_loss         | 2.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.01e+03 |
# |    ep_rew_mean        | 1.74e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4900     |
# |    time_elapsed       | 3925     |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | 0.498    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.344   |
# |    value_loss         | 4.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.04e+03 |
# |    ep_rew_mean        | 1.87e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5000     |
# |    time_elapsed       | 4003     |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.715   |
# |    explained_variance | 0.947    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.16    |
# |    value_loss         | 0.38     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 1.97e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5100     |
# |    time_elapsed       | 4084     |
# |    total_timesteps    | 408000   |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 0.563    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.437   |
# |    value_loss         | 2.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.12e+03 |
# |    ep_rew_mean        | 2.03e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5200     |
# |    time_elapsed       | 4164     |
# |    total_timesteps    | 416000   |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | 0.345    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.185   |
# |    value_loss         | 2.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.09e+03 |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5300     |
# |    time_elapsed       | 4243     |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0.582    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.271   |
# |    value_loss         | 1.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.1e+03  |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5400     |
# |    time_elapsed       | 4325     |
# |    total_timesteps    | 432000   |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0.0865   |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.766   |
# |    value_loss         | 43.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.12e+03 |
# |    ep_rew_mean        | 2.01e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5500     |
# |    time_elapsed       | 4405     |
# |    total_timesteps    | 440000   |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | 0.624    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00667 |
# |    value_loss         | 2.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.09e+03 |
# |    ep_rew_mean        | 2e+03    |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5600     |
# |    time_elapsed       | 4483     |
# |    total_timesteps    | 448000   |
# | train/                |          |
# |    entropy_loss       | -0.428   |
# |    explained_variance | 0.295    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0259  |
# |    value_loss         | 4.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 1.96e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5700     |
# |    time_elapsed       | 4564     |
# |    total_timesteps    | 456000   |
# | train/                |          |
# |    entropy_loss       | -0.395   |
# |    explained_variance | 0.953    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0297  |
# |    value_loss         | 0.39     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.03e+03 |
# |    ep_rew_mean        | 1.88e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5800     |
# |    time_elapsed       | 4644     |
# |    total_timesteps    | 464000   |
# | train/                |          |
# |    entropy_loss       | -0.52    |
# |    explained_variance | 0.401    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.408   |
# |    value_loss         | 6.38     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 1.88e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5900     |
# |    time_elapsed       | 4725     |
# |    total_timesteps    | 472000   |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.525    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.153   |
# |    value_loss         | 5.12     |
# ------------------------------------
# self.n_calls:  30000
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.12e+03 |
# |    ep_rew_mean        | 1.95e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6000     |
# |    time_elapsed       | 4804     |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.93     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0761   |
# |    value_loss         | 0.533    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.14e+03 |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6100     |
# |    time_elapsed       | 4883     |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | -0.624   |
# |    explained_variance | 0.827    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.308    |
# |    value_loss         | 1.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.15e+03 |
# |    ep_rew_mean        | 2e+03    |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6200     |
# |    time_elapsed       | 4963     |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | 0.847    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0875   |
# |    value_loss         | 0.918    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.14e+03 |
# |    ep_rew_mean        | 1.98e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6300     |
# |    time_elapsed       | 5042     |
# |    total_timesteps    | 504000   |
# | train/                |          |
# |    entropy_loss       | -0.695   |
# |    explained_variance | 0.5      |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.211    |
# |    value_loss         | 2.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+03 |
# |    ep_rew_mean        | 1.97e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6400     |
# |    time_elapsed       | 5123     |
# |    total_timesteps    | 512000   |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.831    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.134   |
# |    value_loss         | 1.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 1.93e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6500     |
# |    time_elapsed       | 5205     |
# |    total_timesteps    | 520000   |
# | train/                |          |
# |    entropy_loss       | -0.54    |
# |    explained_variance | 0.505    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00307 |
# |    value_loss         | 5.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.06e+03 |
# |    ep_rew_mean        | 1.91e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6600     |
# |    time_elapsed       | 5286     |
# |    total_timesteps    | 528000   |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.912    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.135    |
# |    value_loss         | 0.503    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.04e+03 |
# |    ep_rew_mean        | 1.89e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6700     |
# |    time_elapsed       | 5365     |
# |    total_timesteps    | 536000   |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | 0.758    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.131    |
# |    value_loss         | 1.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.09e+03 |
# |    ep_rew_mean        | 1.94e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6800     |
# |    time_elapsed       | 5446     |
# |    total_timesteps    | 544000   |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | 0.885    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.118    |
# |    value_loss         | 0.789    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+03 |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 6900     |
# |    time_elapsed       | 5527     |
# |    total_timesteps    | 552000   |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | 0.82     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.211    |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.13e+03 |
# |    ep_rew_mean        | 1.99e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7000     |
# |    time_elapsed       | 5607     |
# |    total_timesteps    | 560000   |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | 0.889    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 0.913    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.12e+03 |
# |    ep_rew_mean        | 1.98e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7100     |
# |    time_elapsed       | 5687     |
# |    total_timesteps    | 568000   |
# | train/                |          |
# |    entropy_loss       | -0.459   |
# |    explained_variance | 0.746    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.197   |
# |    value_loss         | 1.38     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.11e+03 |
# |    ep_rew_mean        | 1.94e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7200     |
# |    time_elapsed       | 5769     |
# |    total_timesteps    | 576000   |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | 0.847    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.021   |
# |    value_loss         | 1.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 1.88e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7300     |
# |    time_elapsed       | 5851     |
# |    total_timesteps    | 584000   |
# | train/                |          |
# |    entropy_loss       | -0.431   |
# |    explained_variance | 0.46     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.584   |
# |    value_loss         | 11.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 1.81e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7400     |
# |    time_elapsed       | 5931     |
# |    total_timesteps    | 592000   |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | 0.768    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.112    |
# |    value_loss         | 1.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.14e+03 |
# |    ep_rew_mean        | 1.85e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7500     |
# |    time_elapsed       | 6011     |
# |    total_timesteps    | 600000   |
# | train/                |          |
# |    entropy_loss       | -0.535   |
# |    explained_variance | 0.84     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.305    |
# |    value_loss         | 1.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.13e+03 |
# |    ep_rew_mean        | 1.82e+03 |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 7600     |
# |    time_elapsed       | 6091     |
# |    total_timesteps    | 608000   |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | 0.832    |
# |    learning_rate      | 6.44e-05 |
# ...
# |    explained_variance | 0.966    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47499    |
# |    policy_loss        | 0.0386   |
# |    value_loss         | 0.189    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.13e+03 |
# |    ep_rew_mean        | 2.5e+03  |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 47600    |
# |    time_elapsed       | 38683    |
# |    total_timesteps    | 3808000  |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47599    |
# |    policy_loss        | 0.032    |
# |    value_loss         | 0.332    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+03 |
# |    ep_rew_mean        | 2.41e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 47700    |
# |    time_elapsed       | 38767    |
# |    total_timesteps    | 3816000  |
# | train/                |          |
# |    entropy_loss       | -0.22    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47699    |
# |    policy_loss        | 0.0737   |
# |    value_loss         | 0.594    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 2.44e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 47800    |
# |    time_elapsed       | 38853    |
# |    total_timesteps    | 3824000  |
# | train/                |          |
# |    entropy_loss       | -0.246   |
# |    explained_variance | 0.879    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47799    |
# |    policy_loss        | 0.0966   |
# |    value_loss         | 0.866    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+03 |
# |    ep_rew_mean        | 2.39e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 47900    |
# |    time_elapsed       | 38937    |
# |    total_timesteps    | 3832000  |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | 0.79     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.0718   |
# |    value_loss         | 2.93     |
# ------------------------------------
# self.n_calls:  240000
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.14e+03 |
# |    ep_rew_mean        | 2.54e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48000    |
# |    time_elapsed       | 39029    |
# |    total_timesteps    | 3840000  |
# | train/                |          |
# |    entropy_loss       | -0.22    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 47999    |
# |    policy_loss        | -0.0226  |
# |    value_loss         | 0.197    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.24e+03 |
# |    ep_rew_mean        | 2.7e+03  |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48100    |
# |    time_elapsed       | 39113    |
# |    total_timesteps    | 3848000  |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48099    |
# |    policy_loss        | 0.0998   |
# |    value_loss         | 0.177    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.21e+03 |
# |    ep_rew_mean        | 2.63e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48200    |
# |    time_elapsed       | 39203    |
# |    total_timesteps    | 3856000  |
# | train/                |          |
# |    entropy_loss       | -0.271   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48199    |
# |    policy_loss        | -0.0209  |
# |    value_loss         | 0.298    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.35e+03 |
# |    ep_rew_mean        | 2.91e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48300    |
# |    time_elapsed       | 39291    |
# |    total_timesteps    | 3864000  |
# | train/                |          |
# |    entropy_loss       | -0.193   |
# |    explained_variance | 0.953    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48299    |
# |    policy_loss        | -0.0587  |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.29e+03 |
# |    ep_rew_mean        | 2.82e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48400    |
# |    time_elapsed       | 39373    |
# |    total_timesteps    | 3872000  |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | 0.945    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48399    |
# |    policy_loss        | -0.023   |
# |    value_loss         | 0.268    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.22e+03 |
# |    ep_rew_mean        | 2.72e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48500    |
# |    time_elapsed       | 39460    |
# |    total_timesteps    | 3880000  |
# | train/                |          |
# |    entropy_loss       | -0.211   |
# |    explained_variance | 0.937    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48499    |
# |    policy_loss        | 0.00435  |
# |    value_loss         | 0.557    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.2e+03  |
# |    ep_rew_mean        | 2.65e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48600    |
# |    time_elapsed       | 39543    |
# |    total_timesteps    | 3888000  |
# | train/                |          |
# |    entropy_loss       | -0.147   |
# |    explained_variance | 0.974    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.0231  |
# |    value_loss         | 0.309    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.16e+03 |
# |    ep_rew_mean        | 2.58e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48700    |
# |    time_elapsed       | 39628    |
# |    total_timesteps    | 3896000  |
# | train/                |          |
# |    entropy_loss       | -0.245   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48699    |
# |    policy_loss        | 0.0487   |
# |    value_loss         | 0.173    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.18e+03 |
# |    ep_rew_mean        | 2.61e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48800    |
# |    time_elapsed       | 39722    |
# |    total_timesteps    | 3904000  |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.971    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48799    |
# |    policy_loss        | 0.0275   |
# |    value_loss         | 0.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.21e+03 |
# |    ep_rew_mean        | 2.68e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 48900    |
# |    time_elapsed       | 39804    |
# |    total_timesteps    | 3912000  |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | 0.984    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48899    |
# |    policy_loss        | 0.0312   |
# |    value_loss         | 0.164    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.22e+03 |
# |    ep_rew_mean        | 2.7e+03  |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49000    |
# |    time_elapsed       | 39887    |
# |    total_timesteps    | 3920000  |
# | train/                |          |
# |    entropy_loss       | -0.125   |
# |    explained_variance | 0.778    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 48999    |
# |    policy_loss        | -0.00753 |
# |    value_loss         | 1.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.16e+03 |
# |    ep_rew_mean        | 2.61e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49100    |
# |    time_elapsed       | 39971    |
# |    total_timesteps    | 3928000  |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | 0.838    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49099    |
# |    policy_loss        | 0.00342  |
# |    value_loss         | 0.788    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 2.44e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49200    |
# |    time_elapsed       | 40058    |
# |    total_timesteps    | 3936000  |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | 0.843    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49199    |
# |    policy_loss        | -0.109   |
# |    value_loss         | 2        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.13e+03 |
# |    ep_rew_mean        | 2.53e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49300    |
# |    time_elapsed       | 40148    |
# |    total_timesteps    | 3944000  |
# | train/                |          |
# |    entropy_loss       | -0.272   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.0139  |
# |    value_loss         | 0.324    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.21e+03 |
# |    ep_rew_mean        | 2.69e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49400    |
# |    time_elapsed       | 40238    |
# |    total_timesteps    | 3952000  |
# | train/                |          |
# |    entropy_loss       | -0.281   |
# |    explained_variance | 0.472    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49399    |
# |    policy_loss        | -0.0402  |
# |    value_loss         | 23       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.24e+03 |
# |    ep_rew_mean        | 2.72e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49500    |
# |    time_elapsed       | 40323    |
# |    total_timesteps    | 3960000  |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.91     |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49499    |
# |    policy_loss        | 0.0193   |
# |    value_loss         | 0.724    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.21e+03 |
# |    ep_rew_mean        | 2.67e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49600    |
# |    time_elapsed       | 40407    |
# |    total_timesteps    | 3968000  |
# | train/                |          |
# |    entropy_loss       | -0.24    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.051   |
# |    value_loss         | 0.243    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.14e+03 |
# |    ep_rew_mean        | 2.55e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49700    |
# |    time_elapsed       | 40493    |
# |    total_timesteps    | 3976000  |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | 0.966    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49699    |
# |    policy_loss        | -0.0145  |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.07e+03 |
# |    ep_rew_mean        | 2.44e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49800    |
# |    time_elapsed       | 40580    |
# |    total_timesteps    | 3984000  |
# | train/                |          |
# |    entropy_loss       | -0.155   |
# |    explained_variance | 0.931    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49799    |
# |    policy_loss        | 0.138    |
# |    value_loss         | 0.437    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.05e+03 |
# |    ep_rew_mean        | 2.38e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 49900    |
# |    time_elapsed       | 40662    |
# |    total_timesteps    | 3992000  |
# | train/                |          |
# |    entropy_loss       | -0.208   |
# |    explained_variance | 0.927    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49899    |
# |    policy_loss        | -0.0153  |
# |    value_loss         | 0.336    |
# ------------------------------------
# self.n_calls:  250000
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 1.08e+03 |
# |    ep_rew_mean        | 2.42e+03 |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 50000    |
# |    time_elapsed       | 40751    |
# |    total_timesteps    | 4000000  |
# | train/                |          |
# |    entropy_loss       | -0.219   |
# |    explained_variance | 0.861    |
# |    learning_rate      | 6.44e-05 |
# |    n_updates          | 49999    |
# |    policy_loss        | 0.0251   |
# |    value_loss         | 0.602    |
# ------------------------------------

# %% [markdown]
# # Testing

# %%
env = make_vec_env('SuperMarioBros-v0', n_envs=1, seed=3994448089, wrapper_class=mario_wrapper)
# env = make_vec_env('SuperMarioBros-1-4-v0', n_envs=1, seed=3994448089, wrapper_class=mario_wrapper)
env = VecFrameStack(env,4,channels_order='last')
env = VecTransposeImage(env)

# %%
model = A2C.load(r'./A2C_3/A2C_3_train./best_model./model_4000000')


obs = env.reset()
obs=obs.copy()
done = True
while True:
    if done:
        state = env.reset()
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    obs=obs.copy()
    env.render()
    #time.sleep(0.01)
# Out:
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d5f5ca06d855> in <module>
#      11     obs, rewards, done, info = env.step(action)
#      12     obs=obs.copy()
# ---> 13     env.render()
#      14     #time.sleep(0.01)
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in render(self, mode)
#     279
#     280     def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> 281         return self.venv.render(mode=mode)
#     282
#     283     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in render(self, mode)
#     279
#     280     def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> 281         return self.venv.render(mode=mode)
#     282
#     283     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# <ipython-input-2-a2ab03b7a7b4> in render(self, *args, **kwargs)
#      22
#      23     def render(self, *args, **kwargs):
# ---> 24         self.env.render()
#      25
#      26     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\nes_py\nes_env.py in render(self, mode)
#     377                 )
#     378             # show the screen on the image viewer
# --> 379             self.viewer.show(self.screen)
#     380         elif mode == 'rgb_array':
#     381             return self.screen
#
# ~\anaconda3\envs\openai\lib\site-packages\nes_py\_image_viewer.py in show(self, frame)
#     146         )
#     147         # send the image to the window
# --> 148         image.blit(0, 0, width=self._window.width, height=self._window.height)
#     149         self._window.flip()
#     150
#
# ~\anaconda3\envs\openai\lib\site-packages\pyglet\image\__init__.py in blit(self, x, y, z, width, height)
#     901
#     902     def blit(self, x, y, z=0, width=None, height=None):
# --> 903         self.get_texture().blit(x, y, z, width, height)
#     904
#     905     def blit_to_texture(self, target, level, x, y, z, internalformat=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\pyglet\image\__init__.py in get_texture(self, rectangle, force_rectangle)
#     832         if (not self._current_texture or
#     833                 (not self._current_texture._is_rectangle and force_rectangle)):
# --> 834             self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     835         return self._current_texture
#     836
#
# ~\anaconda3\envs\openai\lib\site-packages\pyglet\image\__init__.py in create_texture(self, cls, rectangle, force_rectangle)
#     819         internalformat = self._get_internalformat(self.format)
#     820         texture = cls.create(self.width, self.height, internalformat,
# --> 821                              rectangle, force_rectangle)
#     822         if self.anchor_x or self.anchor_y:
#     823             texture.anchor_x = self.anchor_x
#
# ~\anaconda3\envs\openai\lib\site-packages\pyglet\image\__init__.py in create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    1463         id = GLuint()
#    1464         glGenTextures(1, byref(id))
# -> 1465         glBindTexture(target, id.value)
#    1466         glTexParameteri(target, GL_TEXTURE_MIN_FILTER, min_filter)
#    1467         glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#
# ~\anaconda3\envs\openai\lib\site-packages\pyglet\gl\lib.py in errcheck(result, func, arguments)
#      85
#      86
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1baceacf4cb1> in <module>
# ----> 1 env.close()
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in close(self)
#      99
#     100     def close(self) -> None:
# --> 101         self.venv.close()
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in close(self)
#      62
#      63     def close(self) -> None:
# ---> 64         self.venv.close()
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in close(self)
#      65     def close(self) -> None:
#      66         for env in self.envs:
# ---> 67             env.close()
#      68
#      69     def get_images(self) -> Sequence[np.ndarray]:
#
# <ipython-input-2-a2ab03b7a7b4> in close(self)
#      25
#      26     def close(self):
# ---> 27         self.env.close()
#      28
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\monitor.py in close(self)
#     111         Closes the environment
#     112         """
# --> 113         super(Monitor, self).close()
#     114         if self.results_writer is not None:
#     115             self.results_writer.close()
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in close(self)
#     255
#     256     def close(self):
# --> 257         return self.env.close()
#     258
#     259     def seed(self, seed=None):
#
# ~\anaconda3\envs\openai\lib\site-packages\nes_py\nes_env.py in close(self)
#     337         # make sure the environment hasn't already been closed
#     338         if self._env is None:
# --> 339             raise ValueError('env has already been closed.')
#     340         # purge the environment from C++ memory
#     341         _LIB.Close(self._env)
#
# ValueError: env has already been closed.

# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3 import DQN
from gym import Env
from gym.spaces import MultiBinary, Box
import numpy as np
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_util import make_vec_env
import gym
from stable_baselines3.common.atari_wrappers import AtariWrapper
from gym import Wrapper
from stable_baselines3.common.vec_env import VecFrameStack, VecTransposeImage

# %%
# Create custom environment
class Mario(Wrapper):
    def __init__(self, env):
        super(Mario, self).__init__(env)
        self._current_score = 0

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        reward += (info['score'] - self._current_score) / 40.0
        self._current_score = info['score']
        if done:
            if info['flag_get']:
                print('We got it!!!!!')
                reward += 350.0
            else:
                reward -= 50.0
        return state, reward / 10.0, done, info

    def reset(self):
        """Reset the environment and return the initial observation."""
        return self.env.reset()

    def render(self, *args, **kwargs):
        self.env.render()

    def close(self):
        self.env.close()

# %%
monitor_dir = './DQN_Monitor_Logs/'
os.makedirs(monitor_dir,exist_ok=True)

# %%
def mario_wrapper(env):
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = AtariWrapper(env, terminal_on_life_loss=False, clip_reward=False)
    env = Mario(env)
    return env

# %%
env = make_vec_env('SuperMarioBros-v0', seed=3994448089, wrapper_class=mario_wrapper)

env = VecFrameStack(env,4,channels_order='last')
env = VecTransposeImage(env)

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    def __init__(self, check_freq, save_model_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, 'best_model/')
        self.best_mean_reward = -np.inf

    # def _init_callback(self) -> None:
    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    # def _on_step(self) -> bool:
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ',self.n_calls)
            model_path1 = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path1)

        return True

# %%
save_model_dir = './DQN_train_1/'
callback1 = SaveOnBestTrainingRewardCallback(10000, save_model_dir)

# %%
model_param_1={ 'gamma': 0.8692871366327747,'learning_rate': 6.442559213980066e-05 }

# %%
tensorboard_log = r'./DQN_tensorboard_log/'

model = DQN("CnnPolicy", env, verbose=1,
            tensorboard_log = tensorboard_log,**model_param_1)
model.learn(total_timesteps=8000000,callback=callback1)
model.save("mario_model_DQN")
# Out:
# Using cuda device
# Logging to ./DQN_tensorboard_log/DQN_1
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 108      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 3206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 115      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 7913     |
# ----------------------------------
# self.n_calls:  10000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 112      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 11479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 113      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 14937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 1.58e+03 |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 115      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 19112    |
# ----------------------------------
# self.n_calls:  20000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38e+03 |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 115      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 26224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 115      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 29088    |
# ----------------------------------
# self.n_calls:  30000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 116      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 33172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 1.61e+03 |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 116      |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 36995    |
# ----------------------------------
# self.n_calls:  40000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 1.6e+03  |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 117      |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 40282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 117      |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 42826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 117      |
# |    time_elapsed     | 398      |
# |    total_timesteps  | 46793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 117      |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 49987    |
# ----------------------------------
# self.n_calls:  50000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 114      |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 53853    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0217   |
# |    n_updates        | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 111      |
# |    time_elapsed     | 516      |
# |    total_timesteps  | 57612    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0306   |
# |    n_updates        | 1902     |
# ----------------------------------
# self.n_calls:  60000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 109      |
# |    time_elapsed     | 568      |
# |    total_timesteps  | 62049    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0111   |
# |    n_updates        | 3012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 107      |
# |    time_elapsed     | 630      |
# |    total_timesteps  | 67554    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0346   |
# |    n_updates        | 4388     |
# ----------------------------------
# self.n_calls:  70000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 104      |
# |    time_elapsed     | 713      |
# |    total_timesteps  | 74288    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0259   |
# |    n_updates        | 6071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 102      |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 78947    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0432   |
# |    n_updates        | 7236     |
# ----------------------------------
# self.n_calls:  80000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 101      |
# |    time_elapsed     | 834      |
# |    total_timesteps  | 84501    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0277   |
# |    n_updates        | 8625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 100      |
# |    time_elapsed     | 863      |
# |    total_timesteps  | 86958    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0213   |
# |    n_updates        | 9239     |
# ----------------------------------
# self.n_calls:  90000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 99       |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 90705    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0393   |
# |    n_updates        | 10176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 99       |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 93828    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0287   |
# |    n_updates        | 10956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 98       |
# |    time_elapsed     | 977      |
# |    total_timesteps  | 96457    |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.121    |
# |    n_updates        | 11614    |
# ----------------------------------
# self.n_calls:  100000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 97       |
# |    time_elapsed     | 1048     |
# |    total_timesteps  | 102544   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0258   |
# |    n_updates        | 13135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 96       |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 109720   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0438   |
# |    n_updates        | 14929    |
# ----------------------------------
# self.n_calls:  110000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 96       |
# |    time_elapsed     | 1183     |
# |    total_timesteps  | 113978   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0826   |
# |    n_updates        | 15994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 95       |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 116687   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0912   |
# |    n_updates        | 16671    |
# ----------------------------------
# self.n_calls:  120000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 95       |
# |    time_elapsed     | 1264     |
# |    total_timesteps  | 120726   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0713   |
# |    n_updates        | 17681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 95       |
# |    time_elapsed     | 1289     |
# |    total_timesteps  | 122765   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0245   |
# |    n_updates        | 18191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 94       |
# |    time_elapsed     | 1338     |
# |    total_timesteps  | 126975   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0108   |
# |    n_updates        | 19243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 94       |
# |    time_elapsed     | 1370     |
# |    total_timesteps  | 129658   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.101    |
# |    n_updates        | 19914    |
# ----------------------------------
# self.n_calls:  130000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 94       |
# |    time_elapsed     | 1424     |
# |    total_timesteps  | 134074   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.00903  |
# |    n_updates        | 21018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 93       |
# |    time_elapsed     | 1468     |
# |    total_timesteps  | 137709   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.238    |
# |    n_updates        | 21927    |
# ----------------------------------
# self.n_calls:  140000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 93       |
# |    time_elapsed     | 1501     |
# |    total_timesteps  | 140475   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.139    |
# |    n_updates        | 22618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 93       |
# |    time_elapsed     | 1548     |
# |    total_timesteps  | 144347   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0285   |
# |    n_updates        | 23586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 92       |
# |    time_elapsed     | 1602     |
# |    total_timesteps  | 148944   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0621   |
# |    n_updates        | 24735    |
# ----------------------------------
# self.n_calls:  150000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 92       |
# |    time_elapsed     | 1662     |
# |    total_timesteps  | 153874   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.271    |
# |    n_updates        | 25968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 92       |
# |    time_elapsed     | 1694     |
# |    total_timesteps  | 156592   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0811   |
# |    n_updates        | 26647    |
# ----------------------------------
# self.n_calls:  160000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 92       |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 162710   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0574   |
# |    n_updates        | 28177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 91       |
# |    time_elapsed     | 1837     |
# |    total_timesteps  | 168631   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0863   |
# |    n_updates        | 29657    |
# ----------------------------------
# self.n_calls:  170000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 91       |
# |    time_elapsed     | 1877     |
# |    total_timesteps  | 171878   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0107   |
# |    n_updates        | 30469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 91       |
# |    time_elapsed     | 1907     |
# |    total_timesteps  | 174369   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.142    |
# |    n_updates        | 31092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 1.63e+03 |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 91       |
# |    time_elapsed     | 1946     |
# |    total_timesteps  | 177617   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0906   |
# |    n_updates        | 31904    |
# ----------------------------------
# self.n_calls:  180000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 1.62e+03 |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 91       |
# |    time_elapsed     | 1993     |
# |    total_timesteps  | 181436   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0308   |
# |    n_updates        | 32858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 90       |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 185840   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0951   |
# |    n_updates        | 33959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 90       |
# |    time_elapsed     | 2076     |
# |    total_timesteps  | 188467   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.131    |
# |    n_updates        | 34616    |
# ----------------------------------
# self.n_calls:  190000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 90       |
# |    time_elapsed     | 2131     |
# |    total_timesteps  | 192857   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0303   |
# |    n_updates        | 35714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 90       |
# |    time_elapsed     | 2165     |
# |    total_timesteps  | 195711   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0218   |
# |    n_updates        | 36427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 90       |
# |    time_elapsed     | 2185     |
# |    total_timesteps  | 197342   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0629   |
# |    n_updates        | 36835    |
# ----------------------------------
# self.n_calls:  200000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 90       |
# |    time_elapsed     | 2231     |
# |    total_timesteps  | 200984   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.164    |
# |    n_updates        | 37745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 89       |
# |    time_elapsed     | 2277     |
# |    total_timesteps  | 204636   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.146    |
# |    n_updates        | 38658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 89       |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 206441   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.159    |
# |    n_updates        | 39110    |
# ----------------------------------
# self.n_calls:  210000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 89       |
# |    time_elapsed     | 2346     |
# |    total_timesteps  | 210342   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0131   |
# |    n_updates        | 40085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 89       |
# |    time_elapsed     | 2382     |
# |    total_timesteps  | 213278   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0176   |
# |    n_updates        | 40819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 89       |
# |    time_elapsed     | 2434     |
# |    total_timesteps  | 217612   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0359   |
# |    n_updates        | 41902    |
# ----------------------------------
# self.n_calls:  220000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 89       |
# |    time_elapsed     | 2471     |
# |    total_timesteps  | 220602   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0376   |
# |    n_updates        | 42650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 89       |
# |    time_elapsed     | 2510     |
# |    total_timesteps  | 223707   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0699   |
# |    n_updates        | 43426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 88       |
# |    time_elapsed     | 2566     |
# |    total_timesteps  | 228253   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0183   |
# |    n_updates        | 44563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 88       |
# |    time_elapsed     | 2582     |
# |    total_timesteps  | 229537   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0926   |
# |    n_updates        | 44884    |
# ----------------------------------
# self.n_calls:  230000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 88       |
# |    time_elapsed     | 2633     |
# |    total_timesteps  | 233576   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0149   |
# |    n_updates        | 45893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 88       |
# |    time_elapsed     | 2696     |
# |    total_timesteps  | 238705   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0241   |
# |    n_updates        | 47176    |
# ----------------------------------
# self.n_calls:  240000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 1.69e+03 |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 88       |
# |    time_elapsed     | 2732     |
# |    total_timesteps  | 241510   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0471   |
# |    n_updates        | 47877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 88       |
# |    time_elapsed     | 2784     |
# |    total_timesteps  | 245603   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0789   |
# |    n_updates        | 48900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 88       |
# |    time_elapsed     | 2805     |
# |    total_timesteps  | 247278   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.27     |
# |    n_updates        | 49319    |
# ----------------------------------
# self.n_calls:  250000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 88       |
# |    time_elapsed     | 2844     |
# |    total_timesteps  | 250449   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.501    |
# |    n_updates        | 50112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 87       |
# |    time_elapsed     | 2879     |
# |    total_timesteps  | 253046   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0951   |
# |    n_updates        | 50761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 87       |
# |    time_elapsed     | 2924     |
# |    total_timesteps  | 256678   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0739   |
# |    n_updates        | 51669    |
# ----------------------------------
# self.n_calls:  260000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 87       |
# |    time_elapsed     | 2979     |
# |    total_timesteps  | 261134   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.125    |
# |    n_updates        | 52783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 87       |
# |    time_elapsed     | 3020     |
# |    total_timesteps  | 264378   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0472   |
# |    n_updates        | 53594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 1.67e+03 |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 87       |
# |    time_elapsed     | 3061     |
# |    total_timesteps  | 267644   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0945   |
# |    n_updates        | 54410    |
# ----------------------------------
# self.n_calls:  270000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 1.65e+03 |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 87       |
# |    time_elapsed     | 3091     |
# |    total_timesteps  | 270112   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.234    |
# |    n_updates        | 55027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 1.64e+03 |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 87       |
# |    time_elapsed     | 3137     |
# |    total_timesteps  | 273725   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0136   |
# |    n_updates        | 55931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 1.66e+03 |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 87       |
# |    time_elapsed     | 3184     |
# |    total_timesteps  | 277412   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.195    |
# |    n_updates        | 56852    |
# ----------------------------------
# self.n_calls:  280000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 86       |
# |    time_elapsed     | 3251     |
# |    total_timesteps  | 282640   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0578   |
# |    n_updates        | 58159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 86       |
# |    time_elapsed     | 3282     |
# |    total_timesteps  | 285148   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.304    |
# |    n_updates        | 58786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 1.68e+03 |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 86       |
# |    time_elapsed     | 3314     |
# |    total_timesteps  | 287448   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0349   |
# |    n_updates        | 59361    |
# ----------------------------------
# self.n_calls:  290000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 86       |
# |    time_elapsed     | 3361     |
# |    total_timesteps  | 291352   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0862   |
# |    n_updates        | 60337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.42e+03 |
# |    ep_rew_mean      | 1.73e+03 |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 86       |
# |    time_elapsed     | 3414     |
# |    total_timesteps  | 295465   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0314   |
# |    n_updates        | 61366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 1.72e+03 |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 86       |
# |    time_elapsed     | 3440     |
# |    total_timesteps  | 297412   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0136   |
# |    n_updates        | 61852    |
# ----------------------------------
# self.n_calls:  300000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 86       |
# |    time_elapsed     | 3487     |
# |    total_timesteps  | 301185   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0238   |
# |    n_updates        | 62796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 86       |
# |    time_elapsed     | 3521     |
# |    total_timesteps  | 303873   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0232   |
# |    n_updates        | 63468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 86       |
# |    time_elapsed     | 3557     |
# |    total_timesteps  | 306782   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.04     |
# |    n_updates        | 64195    |
# ----------------------------------
# self.n_calls:  310000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 86       |
# |    time_elapsed     | 3598     |
# |    total_timesteps  | 310034   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0343   |
# |    n_updates        | 65008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 1.72e+03 |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 86       |
# |    time_elapsed     | 3648     |
# |    total_timesteps  | 313930   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0298   |
# |    n_updates        | 65982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 85       |
# |    time_elapsed     | 3682     |
# |    total_timesteps  | 316700   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0371   |
# |    n_updates        | 66674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 85       |
# |    time_elapsed     | 3720     |
# |    total_timesteps  | 319672   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.101    |
# |    n_updates        | 67417    |
# ----------------------------------
# self.n_calls:  320000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 85       |
# |    time_elapsed     | 3764     |
# |    total_timesteps  | 323169   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0425   |
# |    n_updates        | 68292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 85       |
# |    time_elapsed     | 3809     |
# |    total_timesteps  | 326808   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0439   |
# |    n_updates        | 69201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 1.71e+03 |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 85       |
# |    time_elapsed     | 3845     |
# |    total_timesteps  | 329510   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.124    |
# |    n_updates        | 69877    |
# ----------------------------------
# self.n_calls:  330000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 1.75e+03 |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 85       |
# |    time_elapsed     | 3888     |
# |    total_timesteps  | 332785   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0456   |
# |    n_updates        | 70696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 1.77e+03 |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 85       |
# |    time_elapsed     | 3909     |
# |    total_timesteps  | 334609   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0295   |
# |    n_updates        | 71152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 1.77e+03 |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 85       |
# |    time_elapsed     | 3960     |
# |    total_timesteps  | 338469   |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0644   |
# |    n_updates        | 72117    |
# ----------------------------------
# self.n_calls:  340000
# ...
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0179   |
# |    n_updates        | 249530   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 1.9e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 70       |
# |    time_elapsed     | 14921    |
# |    total_timesteps  | 1049396  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.143    |
# |    n_updates        | 249848   |
# ----------------------------------
# self.n_calls:  1050000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 1.89e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 70       |
# |    time_elapsed     | 14940    |
# |    total_timesteps  | 1050616  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.124    |
# |    n_updates        | 250153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 1.9e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 70       |
# |    time_elapsed     | 14958    |
# |    total_timesteps  | 1051720  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.222    |
# |    n_updates        | 250429   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 1.9e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 70       |
# |    time_elapsed     | 14972    |
# |    total_timesteps  | 1052782  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.499    |
# |    n_updates        | 250695   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 1.89e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 70       |
# |    time_elapsed     | 14988    |
# |    total_timesteps  | 1053826  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0364   |
# |    n_updates        | 250956   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 1.88e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 70       |
# |    time_elapsed     | 15009    |
# |    total_timesteps  | 1055012  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.213    |
# |    n_updates        | 251252   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.22e+03 |
# |    ep_rew_mean      | 1.89e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 70       |
# |    time_elapsed     | 15026    |
# |    total_timesteps  | 1056069  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.369    |
# |    n_updates        | 251517   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.23e+03 |
# |    ep_rew_mean      | 1.89e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 70       |
# |    time_elapsed     | 15050    |
# |    total_timesteps  | 1057564  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.038    |
# |    n_updates        | 251890   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.24e+03 |
# |    ep_rew_mean      | 1.91e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 70       |
# |    time_elapsed     | 15064    |
# |    total_timesteps  | 1058700  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0927   |
# |    n_updates        | 252174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.17e+03 |
# |    ep_rew_mean      | 1.91e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 70       |
# |    time_elapsed     | 15084    |
# |    total_timesteps  | 1059902  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.104    |
# |    n_updates        | 252475   |
# ----------------------------------
# self.n_calls:  1060000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 1.93e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 70       |
# |    time_elapsed     | 15111    |
# |    total_timesteps  | 1061409  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0205   |
# |    n_updates        | 252852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 1.93e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 70       |
# |    time_elapsed     | 15129    |
# |    total_timesteps  | 1062449  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.433    |
# |    n_updates        | 253112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | 1.91e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 70       |
# |    time_elapsed     | 15146    |
# |    total_timesteps  | 1063408  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0436   |
# |    n_updates        | 253351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+03 |
# |    ep_rew_mean      | 1.91e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 70       |
# |    time_elapsed     | 15159    |
# |    total_timesteps  | 1064321  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.051    |
# |    n_updates        | 253580   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | 1.92e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 70       |
# |    time_elapsed     | 15172    |
# |    total_timesteps  | 1065321  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0725   |
# |    n_updates        | 253830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | 1.93e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 70       |
# |    time_elapsed     | 15189    |
# |    total_timesteps  | 1066285  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.155    |
# |    n_updates        | 254071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+03 |
# |    ep_rew_mean      | 1.93e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 70       |
# |    time_elapsed     | 15206    |
# |    total_timesteps  | 1067376  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0823   |
# |    n_updates        | 254343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 1.96e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 70       |
# |    time_elapsed     | 15232    |
# |    total_timesteps  | 1069133  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.0917   |
# |    n_updates        | 254783   |
# ----------------------------------
# self.n_calls:  1070000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.22e+03 |
# |    ep_rew_mean      | 1.98e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 70       |
# |    time_elapsed     | 15250    |
# |    total_timesteps  | 1070407  |
# | train/              |          |
# |    learning_rate    | 6.44e-05 |
# |    loss             | 0.26     |
# |    n_updates        | 255101   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6f5f5f9f2565> in <module>
#       3 model = DQN("CnnPolicy", env, verbose=1,
#       4             tensorboard_log = tensorboard_log,**model_param_1)
# ----> 5 model.learn(total_timesteps=8000000,callback=callback1)
#       6 model.save("mario_model_DQN")
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     248             tb_log_name=tb_log_name,
#     249             eval_log_path=eval_log_path,
# --> 250             reset_num_timesteps=reset_num_timesteps,
#     251         )
#     252
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     357                 learning_starts=self.learning_starts,
#     358                 replay_buffer=self.replay_buffer,
# --> 359                 log_interval=log_interval,
#     360             )
#     361
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     569
#     570                 # Rescale and perform action
# --> 571                 new_obs, reward, done, infos = env.step(action)
#     572
#     573                 self.num_timesteps += 1
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      81
#      82     def step_wait(self) -> VecEnvStepReturn:
# ---> 83         observations, rewards, dones, infos = self.venv.step_wait()
#      84
#      85         # Transpose the terminal observations
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      42         for env_idx in range(self.num_envs):
#      43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 44                 self.actions[env_idx]
#      45             )
#      46             if self.buf_dones[env_idx]:
#
# <ipython-input-2-058bec7355f9> in step(self, action)
#       6
#       7     def step(self, action):
# ----> 8         state, reward, done, info = self.env.step(action)
#       9         reward += (info['score'] - self._current_score) / 40.0
#      10         self._current_score = info['score']
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in step(self, action)
#     246
#     247     def step(self, action):
# --> 248         return self.env.step(action)
#     249
#     250     def reset(self, **kwargs):
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in step(self, action)
#     280
#     281     def step(self, action):
# --> 282         observation, reward, done, info = self.env.step(action)
#     283         return self.observation(observation), reward, done, info
#     284
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\atari_wrappers.py in step(self, action)
#     137         done = None
#     138         for i in range(self._skip):
# --> 139             obs, reward, done, info = self.env.step(action)
#     140             if i == self._skip - 2:
#     141                 self._obs_buffer[0] = obs
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\core.py in step(self, action)
#     246
#     247     def step(self, action):
# --> 248         return self.env.step(action)
#     249
#     250     def reset(self, **kwargs):
#
# ~\anaconda3\envs\openai\lib\site-packages\nes_py\wrappers\joypad_space.py in step(self, action)
#      72         """
#      73         # take the step and record the output
# ---> 74         return self.env.step(self._action_map[action])
#      75
#      76     def reset(self):
#
# ~\anaconda3\envs\openai\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      88         if self.needs_reset:
#      89             raise RuntimeError("Tried to step environment that needs reset")
# ---> 90         observation, reward, done, info = self.env.step(action)
#      91         self.rewards.append(reward)
#      92         if done:
#
# ~\anaconda3\envs\openai\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
# ---> 18         observation, reward, done, info = self.env.step(action)
#      19         self._elapsed_steps += 1
#      20         if self._elapsed_steps >= self._max_episode_steps:
#
# ~\anaconda3\envs\openai\lib\site-packages\nes_py\nes_env.py in step(self, action)
#     291         self.controllers[0][:] = action
#     292         # pass the action to the emulator as an unsigned byte
# --> 293         _LIB.Step(self._env)
#     294         # get the reward for this step
#     295         reward = self._get_reward()
#
# KeyboardInterrupt:

# %%
env = make_vec_env('SuperMarioBros-1-1-v0', n_envs=1, seed=3994448089, wrapper_class=mario_wrapper)
# env = make_vec_env('SuperMarioBros-1-4-v0', n_envs=1, seed=3994448089, wrapper_class=mario_wrapper)
env = VecFrameStack(env,4,channels_order='last')
env = VecTransposeImage(env)

# %%
model = PPO.load(r'./1_NewExperiment/1_NewExperiment/PPO/PPO_model_DF_0.99/best_model/model_1000000')


obs = env.reset()
obs=obs.copy()
done = True
while True:
    if done:
        state = env.reset()
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    obs=obs.copy()
    env.render()
    time.sleep(0.01)
# Out:
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# C:\Users\admin\anaconda3\envs\openai\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# We got it!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ea7c3cdeb19d> in <module>
#      12     obs=obs.copy()
#      13     env.render()
# ---> 14     time.sleep(0.01)
#
# KeyboardInterrupt:

# %%
env.close()
